# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N=1000
S=1372
alpha=0.3
e=0.61
s=5.67*10**(-8)
C_p=1.05*10**(23)
dt=1*10**(21)
T=np.zeros(N+1)
t=np.zeros(N+1)
T[0]=0
t[0]=0
for j in range(0,N):
    T[j+1]=T[j]+(dt/C_p)*S*(1-alpha)-(dt/C_p)*4*e*s*(T[j]**4)
    t[j+1]=(j+1)*dt
print(t)
# Out:
# [0.00e+00 1.00e+21 2.00e+21 ... 9.98e+23 9.99e+23 1.00e+24]

# %%
plt.plot(t,T)

# %%
a=(dt/C_p)*S*(1-alpha)
a
# Out:
# 9.146666666666667

# %%
sl=(T[2]-T[1])/dt  ##slope
sl
# Out:
# 9.146657444456918e-21

# %%
plt.plot(t[0:10],T[0:10])

# %%
T_m=np.mean(T)

# %%
T_a=T-T_m

# %%
plt.plot(t,T_a)

# %%
plt.plot(t[0:10],T_a[0:10])
